# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %% [markdown]
# 124,404 babies were assessed for the purpose for the study over a timeframe of 15 years. Congenital hypothyroidism occurs in
# 1:2759 live births with a female to male ratio of occurrance at 1.8:1. The main etiologies of CH are dyshormonogenesis (17%), athyreosis (45%) and by thyroid ectopia (24%). The mean age for the commencement of treatment of infants diagnosed in the screening program was 10.3 days.

# %% [markdown]
# # Gender

# %%
#Gender of the ratio of females to males with CH in the study had an incidence of 2:1 meaning that as a female, one's probablity of having CH is twice that of a male. Adapted from https://dziganto.github.io/data%20science/eda/machine%20learning/python/simulated%20data/Simulated-Datasets-for-Faster-ML-Understanding/


# reproducibility
np.random.seed(10)

# number
num = 100

# feature setup

gender = np.random.choice(['F', 'M'], num, p=[0.67, 0.33])
print (gender)
# Out:
# ['M' 'F' 'F' 'M' 'F' 'F' 'F' 'M' 'F' 'F' 'M' 'M' 'F' 'F' 'M' 'F' 'M' 'F'
#  'M' 'M' 'F' 'F' 'F' 'M' 'F' 'F' 'F' 'F' 'F' 'F' 'M' 'F' 'M' 'F' 'F' 'F'
#  'F' 'M' 'F' 'F' 'F' 'M' 'F' 'M' 'F' 'M' 'F' 'M' 'F' 'F' 'F' 'F' 'M' 'F'
#  'F' 'M' 'M' 'F' 'M' 'F' 'F' 'M' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'M' 'F' 'F'
#  'F' 'F' 'F' 'F' 'M' 'M' 'M' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'F' 'F'
#  'F' 'F' 'F' 'M' 'F' 'F' 'M' 'F' 'F' 'F']

# %%
sns.swarmplot(gender, color="blue")

# %% [markdown]
# # Live Births

# %%
#Incidence of Live Births according to the study is 1:2759, meaning that for every one birth of a child with CH, a child without CH is born. 

# reproducibility
np.random.seed(10)
num = 100   
livebirth = np.random.choice(['CH', 'NCH'], num, p=[0.00036, 0.99964])   
print (livebirth)
# Out:
# ['NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH'
#  'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH'
#  'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH'
#  'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH'
#  'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH'
#  'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH'
#  'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH'
#  'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH' 'NCH'
#  'NCH' 'NCH' 'NCH' 'NCH']

# %%
#A swarmplot of livebirth number according to the study
sns.swarmplot(livebirth, color="blue")

# %% [markdown]
# # Etiologies

# %%
#The main causations of Congenital Hyothyroidism in the study are Ectopia 45%, Dyshormonogenesis 24% and Athyreosis 31%

# reproducibility
np.random.seed(10)
num = 100  

etiology = np.random.choice(['E', 'D', 'A'], num, p=[0.45, 0.24, 0.31])
print (etiology)
# Out:
# ['A' 'E' 'D' 'A' 'D' 'E' 'E' 'A' 'E' 'E' 'D' 'A' 'E' 'D' 'A' 'D' 'A' 'E'
#  'A' 'A' 'D' 'E' 'E' 'D' 'E' 'E' 'D' 'D' 'D' 'D' 'A' 'D' 'A' 'E' 'E' 'E'
#  'E' 'A' 'E' 'D' 'D' 'A' 'E' 'A' 'E' 'A' 'E' 'A' 'E' 'E' 'E' 'E' 'A' 'E'
#  'E' 'A' 'A' 'D' 'A' 'E' 'D' 'A' 'D' 'D' 'E' 'E' 'E' 'E' 'E' 'A' 'E' 'E'
#  'E' 'D' 'E' 'E' 'A' 'A' 'A' 'E' 'D' 'D' 'D' 'E' 'E' 'E' 'E' 'E' 'D' 'D'
#  'D' 'E' 'E' 'A' 'E' 'D' 'A' 'E' 'E' 'D']

# %%
sns.swarmplot(etiology, color="blue")

# %% [markdown]
# # Age at Treatment

# %%
# Generates ages randomly
num = 100
age = np.random.randint(6, 15, 100)
print (age)
# Out:
# [14  6 11 14 11 13 14 11 14  7 11  7 10 13 13 13 13 12  6  9 10 10 12 14
#  10  8  7  7 12  9 10 11 10  6  8 14  6 13 12 11 14  8  8  6  7  8  9 11
#  13 14 13 13 12  8  6 10 11 10 12  6 10 12 10 14  6 13  7 13  7  7 11 11
#   6 14  9 13  7 11  8  9 10 11 13 12 14  6 10 12  9 11  9 14  9  6 12  8
#   9  7 10  6]

# %%
#Generates the mean age
np.mean(age)
# Out:
# 10.17

# %%
#Generates the median age
np.median(age)
# Out:
# 10.0

# %%
#Draws a pointplot of Age at Treatment in the study
sns.pointplot(age, color="blue")

# %%
#Creates a dataframe using the variables Gender, Age at Treatment, Etiologies and T4 at Year One
#Adapted from https://www.geeksforgeeks.org/different-ways-to-create-pandas-dataframe/


import pandas as pd 
  
# Activates data in lists. ,
data = {'Gender':['F', 'F', 'F', 'F', 'M', 'M', 'M', 'F','F', 'M', 'F', 'F','M', 'F', 'F', 'F', 'F', 'F','M', 'F', 'F', 'M', 'F', 'F','M'], 
        'Age at Treatment':['19', '12', '15', '16', '13', '17', '15', '12', '10', '10', '14', '20','11', '12', '14', '20', '14', '10', '12', '16', '13', '10', '12', '12', '19'],
        'Etiologies':['E', 'E', 'E', 'D', 'E', 'D', 'E', 'E', 'A', 'E', 'D', 'E', 'E', 'A', 'E', 'A', 'D', 'A', 'E', 'A', 'E', 'D', 'A', 'D', 'D'],
       'T4 at Year One': ['9.4', '24.7', '19.2', '16', '22.4', '15.6', '25', '21.8', '30.5', '25.4', '15.6', '23', '19', '22.7', '11.9', '15.8', '20', '16.2', '23.4', '16.5', '10.2', '11.5', '13.2', '14', '15']
       }      



# Produces the DataFrame 
df = pd.DataFrame(data) 
df[["Age at Treatment", "T4 at Year One"]] = df[["Age at Treatment", "T4 at Year One"]].apply(pd.to_numeric)

# Print the output. 
df
# Out:
#    Gender  Age at Treatment Etiologies  T4 at Year One
# 0       F                19          E             9.4
# 1       F                12          E            24.7
# 2       F                15          E            19.2
# 3       F                16          D            16.0
# 4       M                13          E            22.4
# 5       M                17          D            15.6
# 6       M                15          E            25.0
# 7       F                12          E            21.8
# 8       F                10          A            30.5
# 9       M                10          E            25.4
# 10      F                14          D            15.6
# 11      F                20          E            23.0
# 12      M                11          E            19.0
# 13      F                12          A            22.7
# 14      F                14          E            11.9
# 15      F                20          A            15.8
# ...

# %%
#Obtains information from the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 4 columns):
# Gender              25 non-null object
# Age at Treatment    25 non-null int64
# Etiologies          25 non-null object
# T4 at Year One      25 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 880.0+ bytes

# %%
#Describes information of the dataset
df.describe()
# Out:
#        Age at Treatment  T4 at Year One
# count         25.000000       25.000000
# mean          13.920000       18.320000
# std            3.161223        5.427476
# min           10.000000        9.400000
# 25%           12.000000       15.000000
# 50%           13.000000       16.500000
# 75%           16.000000       22.700000
# max           20.000000       30.500000

# %%
#Gets the mean of the dataset
df.mean()
# Out:
# Age at Treatment    13.92
# T4 at Year One      18.32
# dtype: float64

# %%
#https://docs.scipy.org/doc/numpy/reference/generated/numpy.count_nonzero.html
#Create a numerical variable from 2 genders as they are categorical in nature
#Sort genders 
#'M' = Male, 'F' = Female
gender_ch = ['F', 'M']



#Finding the probability of these in a random sample
#In the study the gender percentages are as follows: . 
gen = np.random.choice(gender_ch, 25, p=[0.67, 0.33])

# https://
print("F: ", np.count_nonzero(gen == 'F'))
print("M: ", np.count_nonzero(gen == 'M'))
# Out:
# F:  16
# M:  9

# %%
#https://docs.scipy.org/doc/numpy/reference/generated/numpy.count_nonzero.html
#Create a numerical variable from all three etiologies as they are categorical in nature
#Sort etiology of CH by birth causation 
#'E' = Ectopia, 'D' = Dyshormonogenesis and 'A' = Athyreosis
etiology_ch = ['E', 'D', 'A']



# Finding the probability of these in a random sample
# In the study the etiology percentages are as follows: Ectopia 45%, Dyshormonogenesis 24% and Athyreosis 31%. 
eti = np.random.choice(etiology_ch, 25, p=[0.45, 0.24, 0.31])

# https://
print("E: ", np.count_nonzero(eti == 'E'))
print("D: ", np.count_nonzero(eti == 'D'))
print("A: ", np.count_nonzero(eti == 'A'))
# Out:
# E:  14
# D:  4
# A:  7

# %%
#https://seaborn.pydata.org/generated/seaborn.relplot.html
#Draws a relplot comparing Age at Treatment and T4 at Year One showing the relationship between the two variables
#We can discern form this plot that t4 at year one and the intervention age for treatment appear to be unrelated, however according to this study a later age for intervention at around 16 to 19 shows that one's t4 levels at year one are slightly reduced which may have some relationship with a compensatory biological response to elevated TSH levels in the body, whereby t4 levels become reduced in a hormonal response to TSH elevations.
sns.relplot(x="Age at Treatment", y="T4 at Year One", kind="line", data=df, height=5, aspect=1)

# %%
#https://seaborn.pydata.org/generated/seaborn.relplot.html
#Draws a relplot comparing Gender and T4 at Year One showing the relationship between the two variables
#We can deem for this plot that t4 at year one was slightly higher for the males in this study than for females
sns.relplot(x="Gender", y="T4 at Year One", kind="line", data=df, height=5, aspect=1)

# %%
#https://seaborn.pydata.org/generated/seaborn.relplot.html
#Draws a relplot comparing Gender and Age at Treatment showing the relationship between the two variables
#We can discern from the plot that females have the latest intervention age for treatment in this study 
sns.relplot(x="Gender", y="Age at Treatment", kind="line", data=df, height=5, aspect=1)

# %%
#https://seaborn.pydata.org/generated/seaborn.relplot.html
#Draws a relplot comparing Etiology and T4 at Year One showing the relationship between the two variables7
#From the plot we can see that Dyshormonogenesis appears to have the lowest T4 at year one for the purposes of this study, with Athreosis and Ectopia showing little differences of T4 at year one
sns.relplot(x="Etiologies", y="T4 at Year One", kind="line", data=df, height=5, aspect=1)

# %%
#https://seaborn.pydata.org/generated/seaborn.relplot.html
#Draws a relplot comparing Etiology and Age at Treatment showing the relationship between the two variables
#From the plot we can discern that Dyshormonogenesis has the latest age for treatment peaking at around 14 days old for the purposes of this study, with Ectopia having the next latest intervention, closely followed by Athreosis
sns.relplot(x="Etiologies", y="Age at Treatment", kind="line", data=df, height=5, aspect=1)

# %%
#https://docs.scipy.org/doc/numpy/reference/generated/numpy.linspace.html
#Age by t4
a = np.linspace(10, 20, 50)
t = np.linspace(10.2, 30.5, 50)


plt.plot(a, t, 'b')
plt.title("Age by T4")
plt.xlabel("Age")
plt.ylabel("T4")
plt.grid()

# %%
#Modelling the Age at Treatment data on a normal distribution
#Obtain the mean and standard deviation of the Age At Treatment data
#Adapted from https://towardsdatascience.com/using-standard-deviation-in-python-77872c32ba9b
import numpy as np
df = age
age =[19, 12, 15, 16, 13, 17, 15, 12, 10, 10, 14, 20, 11, 12, 14, 20, 14, 10, 12, 16, 13, 10, 12, 12, 19]
print('Mean:', np.mean(age))
print('Standard Deviation:', np.std(age))
# Out:
# Mean: 13.92
# Standard Deviation: 3.09735370921695

# %%
#Obtain the distribution of the Age at Treatment data
#https://towardsdatascience.com/using-standard-deviation-in-python-77872c32ba9b
mean = 13.92
sd = 3.09
age_samp = np.random.normal(mean, sd, 100)
plt.plot(age_samp, stats.norm.pdf(age_samp, 13.92, 3.09))
plt.xlabel("Age at Treatment")
plt.ylabel("")
plt.show()

# %%
#https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.random.normal.html
#Call on the function np.random.normal to generate a conclusion from the normal distribution with a mean of 0 and standard deviation of 1.
np.random.normal(size = 1, loc = 0, scale = 1)
# Out:
# array([1.23360599])

# %%
# call on the function np.random.normal to generate a conclusion from the normal distribution with a mean of 0 and standard deviation of 1.
x = np.random.normal()
x = range(100)
y = np.random.uniform(20, 10, size=100)

plt.scatter(x, y)
plt.show()

# %%
#Draws 10 numbers from the normal distribution, the value 10 is passed as the size specification, we are specifying that we want to produce a NumPy array of 10 values, drawing from the normal distribution. Also, because we have not identified values for loc and scale, they will revert to loc = 0 and scale = 1.
age = np.random.normal(10)
print(age)
# Out:
# 10.380926817053146

# %%
#Obtain the mean and standard deviation of T4 at Year One
#Adapted from https://towardsdatascience.com/using-standard-deviation-in-python-77872c32ba9b
import numpy as n
df1 = t4
t4 =[9.4, 24.7, 19.2, 16, 22.4, 15.6, 25, 21.8, 30.5, 25.4, 15.6, 23, 19, 22.7, 11.9, 15.8, 20, 16.2, 23.4, 16.5, 10.2, 11.5, 13.2, 14, 15]
print('Mean:', np.mean(t4))
print('Standard Deviation:', np.std(t4))
# Out:
# Mean: 18.319999999999997
# Standard Deviation: 5.31781910184993

# %%
#Modelling the T4 at Year One data on a normal distribution
#Obtain the mean and standard deviation of the Age At Treatment data
#https://towardsdatascience.com/using-standard-deviation-in-python-77872c32ba9b
mean = 18.319999999999997
sd = 5.31781910184993
dfsamp = np.random.normal(mean, sd, 100)
plt.plot(dfsamp, stats.norm.pdf(dfsamp, 13.92, 3.09))
plt.xlabel("T4 at Year One")
plt.ylabel("")
plt.show()

# %%
#Adapted from https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.random.normal.html
#Call on the function np.random.normal to generate a conclusion from the normal distribution with a mean of 0 and standard deviation of 1.
x = np.random.normal()
x = range(100)
y = np.random.uniform(30.5, 10.2, size=100)

plt.scatter(x, y)
plt.show()

# %%
#Draws 10 numbers from the normal distribution, the value 10 is passed as the size specification, we are specifying that we want to produce a NumPy array of 10 values, drawing from the normal distribution. Also, because we have not identified values for loc and scale, they will revert to loc = 0 and scale = 1.
np.random.normal(10)
# Out:
# 10.46689945025526

# %%
#Plots a histogram of the Age at Treatment and T4 at Year One variables.
#Adapted from http://matplotlib.org/examples/statistics/histogram_demo_multihist.html
import random
import numpy
from matplotlib import pyplot


age = [random.gauss(20, 10) for _ in range(25)]
t4 = [random.gauss(30.5, 10.2) for _ in range(25)]

bins = numpy.linspace(0, 30, 50)

pyplot.hist(age, bins, alpha=0.5, label='age')
pyplot.hist(t4, bins, alpha=0.5, label='t4')
pyplot.legend(loc='upper right')
pyplot.show()

# %%
#Plots a histogram of the Age at Treatment and T4 at Year One variables.
#Adapted from http://matplotlib.org/examples/statistics/histogram_demo_multihist.html
import random
import numpy
from matplotlib import pyplot


age = [random.gauss(20, 10) for _ in range(25)]
t4 = [random.gauss(30.5, 10.2) for _ in range(25)]

pyplot.scatter(age, t4, label=['age', 't4'])

pyplot.legend(loc='upper right')
pyplot.show()

# %%
#Adapted from https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-deep')

age = np.random.normal(20, 10, 25)
t4 = np.random.normal(30.5, 10.2, 25)
bins = np.linspace(0, 10, 30)

plt.hist([age, t4], bins, label=['age', 't4'])
plt.legend(loc='upper right')
plt.show()

# %%
#Adapted from https://www.sharpsightlabs.com/blog/numpy-random-normal/
n_df = np.random.normal(size = 100, loc = 0, scale = 1)
plt.hist(n_df)
# Out:
# (array([ 2.,  3.,  9., 14., 23., 16., 20.,  8.,  2.,  3.]),
#  array([-2.85456336, -2.30610125, -1.75763914, -1.20917702, -0.66071491,
#         -0.1122528 ,  0.43620932,  0.98467143,  1.53313354,  2.08159566,
#          2.63005777]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# References
#
#
# http://matplotlib.org/examples/statistics/histogram_demo_multihist.html
#
# https://towardsdatascience.com/using-standard-deviation-in-python-77872c32ba9b
#
# https://www.sharpsightlabs.com/blog/numpy-random-normal/
#
# https://dziganto.github.io/data%20science/eda/machine%20learning/python/simulated%20data/Simulated-Datasets-for-Faster-ML-Understanding/
#
# https://www.geeksforgeeks.org/different-ways-to-create-pandas-dataframe/
#
# http://dept.stat.lsa.umich.edu/~kshedden/Python-Workshop/stats_calculations.html
#
# https://towardsdatascience.com/using-standard-deviation-in-python-77872c32ba
#
# https://seaborn.pydata.org/generated/seaborn.relplot.html
#
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.linspace.html
#
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.linspace.html
#
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.count_nonzero.html
#
# https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html
#
# https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.random.normal.html
